# %%
import requests
import pandas as pd
from urllib import parse
import json
import time
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

api_key = "RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8"#api_key

champions_id={      #champion list
    266: "Aatrox",
    412: "Thresh",
    23: "Tryndamere",
    79: "Gragas",
    69: "Cassiopeia",
    136: "Aurelion Sol",
    13: "Ryze",
    78: "Poppy",
    14: "Sion",
    1: "Annie",
    202: "Jhin",
    43: "Karma",
    111: "Nautilus",
    240: "Kled",
    99: "Lux",
    103: "Ahri",
    2: "Olaf",
    112: "Viktor",
    34: "Anivia",
    27: "Singed",
    86: "Garen",
    127: "Lissandra",
    57: "Maokai",
    25: "Morgana",
    28: "Evelynn",
    105: "Fizz",
    74: "Heimerdinger",
    238: "Zed",
    68: "Rumble",
    82: "Mordekaiser",
    37: "Sona",
    96: "Kog'Maw",
    55: "Katarina",
    117: "Lulu",
    22: "Ashe",
    30: "Karthus",
    12: "Alistar",
    122: "Darius",
    67: "Vayne",
    110: "Varus",
    77: "Udyr",
    89: "Leona",
    126: "Jayce",
    134: "Syndra",
    80: "Pantheon",
    92: "Riven",
    121: "Kha'Zix",
    42: "Corki",
    268: "Azir",
    51: "Caitlyn",
    76: "Nidalee",
    85: "Kennen",
    3: "Galio",
    45: "Veigar",
    432: "Bard",
    150: "Gnar",
    90: "Malzahar",
    104: "Graves",
    254: "Vi",
    10: "Kayle",
    39: "Irelia",
    64: "Lee Sin",
    420: "Illaoi",
    60: "Elise",
    106: "Volibear",
    20: "Nunu",
    4: "Twisted Fate",
    24: "Jax",
    102: "Shyvana",
    429: "Kalista",
    36: "Dr. Mundo",
    427: "Ivern",
    131: "Diana",
    223: "Tahm Kench",
    63: "Brand",
    113: "Sejuani",
    8: "Vladimir",
    154: "Zac",
    421: "Rek'Sai",
    133: "Quinn",
    84: "Akali",
    163: "Taliyah",
    18: "Tristana",
    120: "Hecarim",
    15: "Sivir",
    236: "Lucian",
    107: "Rengar",
    19: "Warwick",
    72: "Skarner",
    54: "Malphite",
    157: "Yasuo",
    101: "Xerath",
    17: "Teemo",
    75: "Nasus",
    58: "Renekton",
    119: "Draven",
    35: "Shaco",
    50: "Swain",
    91: "Talon",
    40: "Janna",
    115: "Ziggs",
    245: "Ekko",
    61: "Orianna",
    114: "Fiora",
    9: "Fiddlesticks",
    31: "Cho'Gath",
    33: "Rammus",
    7: "LeBlanc",
    16: "Soraka",
    26: "Zilean",
    56: "Nocturne",
    222: "Jinx",
    83: "Yorick",
    6: "Urgot",
    203: "Kindred",
    21: "Miss Fortune",
    62: "Wukong",
    53: "Blitzcrank",
    98: "Shen",
    201: "Braum",
    5: "Xin Zhao",
    29: "Twitch",
    11: "Master Yi",
    44: "Taric",
    32: "Amumu",
    41: "Gangplank",
    48: "Trundle",
    38: "Kassadin",
    161: "Vel'Koz",
    143: "Zyra",
    267: "Nami",
    59: "Jarvan IV",
    81: "Ezreal",
    350: "Yuumi",
    145: "Kai'sa",
    518: "Neeko",
    142: "Zoe",
    498: "Xayah",
    517: "Sylas",
    141: "Kayn",
    516: "Ornn",
    555: "Pyke",
    164: "Camille",
    246: "Qiyana",
    497: "Rakan",
    235: "Senna",
    523: "Aphelios",
    875: "Sett",
    876: "Lillia",
    777: "Yone",
    360: "Samira",
    147: "Seraphine",
    526: "Rell",
    234: "Viego",
    887: "Gwen",
    166: "Akshan"
}
queue_type = {    #queue type list
    450: "ARAM",
    440: "Flex 5:5 Rank",
    430: "Normal",
    420: "Solo Rank",
    830: "Bot"
}

# %%
CHALLENGER_URL ="https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key="+api_key
MASTER_URL ="https://kr.api.riotgames.com/lol/league/v4/masterleagues/by-queue/RANKED_SOLO_5x5?api_key="+api_key
GRANDMASTER_URL ="https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5?api_key="+api_key
summoner_id_list = []
#top tier api list

URL_list = [CHALLENGER_URL,MASTER_URL,GRANDMASTER_URL]

for x in URL_list:
    req = requests.get(x)
    for i in range(len(req.json()['entries'])):
        summoner_id_list.append(req.json()['entries'][i]['summonerId'])
        
    #top tier summonerid append in summoner_id_list

# %%
summoner_info_URL = "https://kr.api.riotgames.com/lol/summoner/v4/summoners/{}?api_key="+api_key
account_id = []     #summoner info URL
#because i want to get account id.

for x in range(len(summoner_id_list)):
    summoner_info_req = requests.get(summoner_info_URL.format(summoner_id_list[x]))
    if summoner_info_req.status_code == 200:     #status_code is 200, pass(beacuase api request limit)
        pass
    elif summoner_info_req.status_code == 429:
        start_time = time.time()
        while True:
            if summoner_info_req.status_code == 429:
                time.sleep(82)

                summoner_info_req = requests.get(summoner_info_URL.format(summoner_id_list[x]))

            elif summoner_info_req.status_code == 200:
                break
    account_id.append(summoner_info_req.json()['accountId'])

# %%
#save pickle
 
with open( "account_id_list", "wb" ) as file:
    pickle.dump( account_id, file)

# %%
with open( "account_id_list", "rb" ) as file:     #load pickle
    account_id_pickle_data = pickle.load(file)

# %%
matchlists = "https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/{}?champion={}&beginTime={}&api_key="+api_key
#accountId, champion, beginTime(unix)
champion_num = 166
begin_time = 1627077600000 #lol last patch day
game_id = []
for x in range(len(account_id_pickle_data)):
    match_req = requests.get(matchlists.format(account_id_pickle_data[x],champion_num,begin_time))
    if match_req.status_code == 404 or match_req.status_code == 403:
        continue
    elif match_req.status_code == 200:
        pass
    
    elif match_req.status_code == 429:
        start_time = time.time()
        while True:
            if match_req.status_code == 429:
                time.sleep(82)

                match_req = requests.get(matchlists.format(account_id_pickle_data[x],champion_num,begin_time))

            elif match_req.status_code == 200 or match_req.status_code == 404 or match_req.status_code == 403:
                break
    if match_req.status_code == 404 or match_req.status_code == 403:
        continue
    elif match_req.status_code == 503:
        break
    for x in range(len(match_req.json()['matches'])):
        game_id.append(match_req.json()['matches'][x]['gameId'])
# Out:
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/Qzm35_yyPh1CJLZU9w266ayowupCIiMm3lVvnAVwhq74oo5PxHYwi9TD?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# Qzm35_yyPh1CJLZU9w266ayowupCIiMm3lVvnAVwhq74oo5PxHYwi9TD
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/e8SI_Q-rg92ANo2OBNd7T2Da_JkXY_zC_jFGq3ulzb0?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# e8SI_Q-rg92ANo2OBNd7T2Da_JkXY_zC_jFGq3ulzb0
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/nvU5nWR2-kbYVFFcODMTTTZoBL0gg_zYQspOyPLd4H5V6A8?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# nvU5nWR2-kbYVFFcODMTTTZoBL0gg_zYQspOyPLd4H5V6A8
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/IxNHmoJLzMPW_VPqebAHtxT7M5RpmFbf16Xye9NbyTRgl_xnxNp_vR9j?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# IxNHmoJLzMPW_VPqebAHtxT7M5RpmFbf16Xye9NbyTRgl_xnxNp_vR9j
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/E_4mR_ZrDPjkg-nvL-xfJX8Vy4Nf78W-NXY9ULYBMhm_mhU?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# E_4mR_ZrDPjkg-nvL-xfJX8Vy4Nf78W-NXY9ULYBMhm_mhU
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/69ONFY2mSYVBJCpQx1mH4vWsoYu2L33JA7pXgkYE3BFl0NDG6yc8mNTO?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 69ONFY2mSYVBJCpQx1mH4vWsoYu2L33JA7pXgkYE3BFl0NDG6yc8mNTO
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/KooqMnR8Vgyck_N-PPWgl_-G7E77_y-RRbBCa22nn5-x?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# KooqMnR8Vgyck_N-PPWgl_-G7E77_y-RRbBCa22nn5-x
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/MGi8somOp78Hz8HQRUXABaX8r594VKu9-xMUj-r1NofA?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# MGi8somOp78Hz8HQRUXABaX8r594VKu9-xMUj-r1NofA
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/J8oj9wvwepQ6D6pZTz6hSME1eOkltrMwub98b89YLSqpyzU?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# J8oj9wvwepQ6D6pZTz6hSME1eOkltrMwub98b89YLSqpyzU
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/T0mfyeNYGzlxZ_CUMSQXoQgHBPM89yVr5xZRomgkVWzsAl3I5bVFLjpH?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# T0mfyeNYGzlxZ_CUMSQXoQgHBPM89yVr5xZRomgkVWzsAl3I5bVFLjpH
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/8C5-obyMV2FsjNrb-mwSR4f7JIegdrNQ4PTxsVdmhw007rQXRad6B9uv?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 8C5-obyMV2FsjNrb-mwSR4f7JIegdrNQ4PTxsVdmhw007rQXRad6B9uv
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/UnBz7bFd7bMJrButvR70Lr5XvQg4CyWZC2vgtVDn7eqvH2M?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# UnBz7bFd7bMJrButvR70Lr5XvQg4CyWZC2vgtVDn7eqvH2M
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/qU3quZWY2TJ3h3fb-4MV1UG9ANn_YCzuwkD1ctKsz1wmC5c?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# qU3quZWY2TJ3h3fb-4MV1UG9ANn_YCzuwkD1ctKsz1wmC5c
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/4ENourd4fWrt_1hokuKh6pGqV7fb3Aiqd00pT5Lu3-JHZWAZMeHtUrIi?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 4ENourd4fWrt_1hokuKh6pGqV7fb3Aiqd00pT5Lu3-JHZWAZMeHtUrIi
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/RlPCEVYQFx_6zHCvgQVSc9wMgawZ6mlwpYNNYGO5oSnz892BTLGgB1ju?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# RlPCEVYQFx_6zHCvgQVSc9wMgawZ6mlwpYNNYGO5oSnz892BTLGgB1ju
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/7NOdFNYGOFwJUgeUOfC3GvoARATf7hziDdac0iLnd6AR?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 7NOdFNYGOFwJUgeUOfC3GvoARATf7hziDdac0iLnd6AR
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/sKqGuNgPwwUbzUAEjvfYQ_LsnbmNxdehqWs-pCwGPr6pkWfO6HrZyPnn?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# sKqGuNgPwwUbzUAEjvfYQ_LsnbmNxdehqWs-pCwGPr6pkWfO6HrZyPnn
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/G5rg7QClJFVzaLHXPQlDbllKvQsbweSnFhNCtdRcG7rOa7U?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# G5rg7QClJFVzaLHXPQlDbllKvQsbweSnFhNCtdRcG7rOa7U
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/a6Q5o3SvkSjStlSOk-3kBpfP5RnbBonb4IVu92K6q0IHi0k2BtG7G5GO?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# a6Q5o3SvkSjStlSOk-3kBpfP5RnbBonb4IVu92K6q0IHi0k2BtG7G5GO
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/0y3EUsxnBT0FNf9rV3feicb1AdQLGSjdpA-20liU5ZMSef4?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 0y3EUsxnBT0FNf9rV3feicb1AdQLGSjdpA-20liU5ZMSef4
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/Uvg3Ux5CxO1o2WXpQXDbDPyDcQAM-NekO-hqFIAOA7s3rUs?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# Uvg3Ux5CxO1o2WXpQXDbDPyDcQAM-NekO-hqFIAOA7s3rUs
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/WGiizychZI7z42yOjMfdONE-hATh5ztjoavgigMGwIOpmkw?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# WGiizychZI7z42yOjMfdONE-hATh5ztjoavgigMGwIOpmkw
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/DTQ49L4dfFxAHNDSU04Yrkr8gHfsUmejiEXhZvuMlDqyAnUvK34Ld0iR?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# DTQ49L4dfFxAHNDSU04Yrkr8gHfsUmejiEXhZvuMlDqyAnUvK34Ld0iR
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/RUIEWfkSJC5uE4fqGsYqanRiZxpWjKXEVtksDttqRXcQ9ZYty_RrXXTT?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# RUIEWfkSJC5uE4fqGsYqanRiZxpWjKXEVtksDttqRXcQ9ZYty_RrXXTT
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/YztBQL5vc7CuEa5z5nR3qzxM7oA2E6nhYlsYsdIg92kQ?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# YztBQL5vc7CuEa5z5nR3qzxM7oA2E6nhYlsYsdIg92kQ
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/C3CPqbcm6qP0t_cjtIKrl5bclxaFQ_4Pkfckf84pEX3lrLY?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# C3CPqbcm6qP0t_cjtIKrl5bclxaFQ_4Pkfckf84pEX3lrLY
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/IqPVtPm5l0sS-Ne8dtLy68QK2GqFG3Kxzgc26LCC8-Ugeq8BTld97nVN?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# IqPVtPm5l0sS-Ne8dtLy68QK2GqFG3Kxzgc26LCC8-Ugeq8BTld97nVN
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/MLy5Kb08eoFcIzXBQmrCdw9OBFTaFUxorKt1x06mTvjF0to?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# MLy5Kb08eoFcIzXBQmrCdw9OBFTaFUxorKt1x06mTvjF0to
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/NZogT6IjCRMiCflzRla_Woi1v0bDfIUVCmHjB2jksq0RlUIy8ob3j13T?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# NZogT6IjCRMiCflzRla_Woi1v0bDfIUVCmHjB2jksq0RlUIy8ob3j13T
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/FrolNAQsXqaLdxEG766ECjh9YglMlpMpiqeIRn_WHWp6cDE?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# FrolNAQsXqaLdxEG766ECjh9YglMlpMpiqeIRn_WHWp6cDE
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/DizZfgBCW9hT5fmFDRhuKly9Pysorj1-sdXZLTsqXDW7jvngIujmwMwd?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# DizZfgBCW9hT5fmFDRhuKly9Pysorj1-sdXZLTsqXDW7jvngIujmwMwd
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/v9O2a_RI0f4-Xfb18-WdiEqH8gQxR9VhvgvVODmkLq1t1ZqNsXYe64nC?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# v9O2a_RI0f4-Xfb18-WdiEqH8gQxR9VhvgvVODmkLq1t1ZqNsXYe64nC
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/8GoMv-zvtkQ7Gc4hEiQVzBS8L9bAXCBiK-wbvMCpQxyJCBK5nPTHD5yg?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 8GoMv-zvtkQ7Gc4hEiQVzBS8L9bAXCBiK-wbvMCpQxyJCBK5nPTHD5yg
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/tBtZr9vJZQFk3JTvYZ5_eKm9ZX-5qtuXP_wfBBOnXFHAmJA?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# tBtZr9vJZQFk3JTvYZ5_eKm9ZX-5qtuXP_wfBBOnXFHAmJA
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/7LbeT_bGy-ZkFuXdz4By7By8fE2j9wHUlAY0jxDtNKukddE?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 7LbeT_bGy-ZkFuXdz4By7By8fE2j9wHUlAY0jxDtNKukddE
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/DKE9Iqjw0ZwTGXJRwzSkbPlgL-99PoCNtatl5IMZnV7mH7hof17pXl_o?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# DKE9Iqjw0ZwTGXJRwzSkbPlgL-99PoCNtatl5IMZnV7mH7hof17pXl_o
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/nmcDlN7pmxde7IvRlxdbJFazLfbkh0_SJisSfKjzbZE24R4jTXQ1ihGP?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# nmcDlN7pmxde7IvRlxdbJFazLfbkh0_SJisSfKjzbZE24R4jTXQ1ihGP
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/nRhvHqaPDnb7XB_YChZRF9qqKATXsUVJRBQLh5VhCb2H6fImIp03ifTg?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# nRhvHqaPDnb7XB_YChZRF9qqKATXsUVJRBQLh5VhCb2H6fImIp03ifTg
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/RTIIbApK4QMGtUuDfQ70H8K_F-JqyzcfyWHUmt8gKRhrUc2eKvUwJivC?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# RTIIbApK4QMGtUuDfQ70H8K_F-JqyzcfyWHUmt8gKRhrUc2eKvUwJivC
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/UMh_zo3Lt6wHSHj8BLszhCOY6a8mqpSj9eyDPMXIKIsNp-rDC0wlbqOR?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# UMh_zo3Lt6wHSHj8BLszhCOY6a8mqpSj9eyDPMXIKIsNp-rDC0wlbqOR
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/4DRbAj73hrlEzVNOCd-b72xq1TCmAg9RGDzoGcIjNiBOQ-4?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 4DRbAj73hrlEzVNOCd-b72xq1TCmAg9RGDzoGcIjNiBOQ-4
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uK1BRbz1Sv1dsVbwQJWXV26i-M6IKrKXu45CQc81eC0LqdQczMJlz1sl?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# uK1BRbz1Sv1dsVbwQJWXV26i-M6IKrKXu45CQc81eC0LqdQczMJlz1sl
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/vkKMIAybKMd8TQPRUsOlGQJH3F0RugvzSbqwDLXZ2y8CqUA1dORQDkpO?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# vkKMIAybKMd8TQPRUsOlGQJH3F0RugvzSbqwDLXZ2y8CqUA1dORQDkpO
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/811IhRkguPutHxQc5RM7AJnu7iS7dek51v4Qxv_hIVThBIwMDlLzy_Nj?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 811IhRkguPutHxQc5RM7AJnu7iS7dek51v4Qxv_hIVThBIwMDlLzy_Nj
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/s5mn9MsYXcWxridhMlXh_il8SXEBSo---QUG-BNR0cbWg0Q?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# s5mn9MsYXcWxridhMlXh_il8SXEBSo---QUG-BNR0cbWg0Q
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/XX8IJdB9eu9Zo3dA_ZGdn2KYSHUJr0eqtqCiZhtJg9qBgS4?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# XX8IJdB9eu9Zo3dA_ZGdn2KYSHUJr0eqtqCiZhtJg9qBgS4
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/QJRGpYwRrOTmw1AElAwXo3iWSStOREPCpT2ijnZEhwyt1uI4hL5EnFO0?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# QJRGpYwRrOTmw1AElAwXo3iWSStOREPCpT2ijnZEhwyt1uI4hL5EnFO0
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/WKf0BS1zwRloxJajwmNtbQV4rytMd3xNDBDNZjaVSctYbOk?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# WKf0BS1zwRloxJajwmNtbQV4rytMd3xNDBDNZjaVSctYbOk
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/P2lspEPcQS65cnCD0bt6OAryzd5YXNRfa7Hjo5bKT7Zy?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# P2lspEPcQS65cnCD0bt6OAryzd5YXNRfa7Hjo5bKT7Zy
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/Bq2bKi5Hoflabnz4ss5WM8BOtbKXWtvv3lb46wFjdnpJVjE?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# Bq2bKi5Hoflabnz4ss5WM8BOtbKXWtvv3lb46wFjdnpJVjE
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/ALgk7ecMl-5avylZp_yaSektqIaFBTqx_7PQ-SRn1Tc_poubWHqi6ZeM?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# ALgk7ecMl-5avylZp_yaSektqIaFBTqx_7PQ-SRn1Tc_poubWHqi6ZeM
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/beWREixQgC3pIqV-L04TAsvwOP2Z6cYG674aKLznJkew0Y8?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# beWREixQgC3pIqV-L04TAsvwOP2Z6cYG674aKLznJkew0Y8
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/Trl2o4mIG0mICydLqZUtotEG6Ktc4u-XOxiY0ud13fU0TdgoTT2Z8_Av?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# Trl2o4mIG0mICydLqZUtotEG6Ktc4u-XOxiY0ud13fU0TdgoTT2Z8_Av
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/BsLu__7WljbaEMgRhZsASEMAPMvH_lm9VioJ6bbGU_GM?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# BsLu__7WljbaEMgRhZsASEMAPMvH_lm9VioJ6bbGU_GM
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/wPDdud7KxbST_7cXiKY-NUTCP35COaYVUtUFk3CmsSubPFo?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# wPDdud7KxbST_7cXiKY-NUTCP35COaYVUtUFk3CmsSubPFo
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/Qb8_W0-cdKaTEFcgd7UsgecfbA_48K0eRvw2gydeibZjG9Q?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# Qb8_W0-cdKaTEFcgd7UsgecfbA_48K0eRvw2gydeibZjG9Q
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/8-yGeczMX9n5bwgMhwHz-Hbu-SeLzK64KiYg9ghT57HQBwM1XjN4O2cD?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 8-yGeczMX9n5bwgMhwHz-Hbu-SeLzK64KiYg9ghT57HQBwM1XjN4O2cD
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/GbWbf9WQxgfb2rv0YNYMlG72_r86pmzZEKpm1q0QvyA6eojot3jZ0bHz?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# GbWbf9WQxgfb2rv0YNYMlG72_r86pmzZEKpm1q0QvyA6eojot3jZ0bHz
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/jMqUao5aIQMOG1b0NTxlhiQfF3YgX7td2s53LRSMCLuL?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# jMqUao5aIQMOG1b0NTxlhiQfF3YgX7td2s53LRSMCLuL
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/d55FeP3MiV4Ds1A5fQjJRZowrYS5NTKDDqVHIFMjh5EnxuMdnHgxfgmx?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# d55FeP3MiV4Ds1A5fQjJRZowrYS5NTKDDqVHIFMjh5EnxuMdnHgxfgmx
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/_non35VkAEtliy3TjUO0zAXQ6i0JdS2W5dp729KWnrN3WPLIW2DOANTW?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# _non35VkAEtliy3TjUO0zAXQ6i0JdS2W5dp729KWnrN3WPLIW2DOANTW
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/9tBqffkN-hJSnifiEyRZZcIbfTTipM9-yiAETIVU19HCjN_V11NY8f3h?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 9tBqffkN-hJSnifiEyRZZcIbfTTipM9-yiAETIVU19HCjN_V11NY8f3h
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/b1Ku5ituaBQnt3t0XYAUx13tvyDvaqU7fcwjHZ0EAe9UOo0?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# b1Ku5ituaBQnt3t0XYAUx13tvyDvaqU7fcwjHZ0EAe9UOo0
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uRC6l4lbBVWqY_cBLsEeBDjCmAHMWKgJdjLb7Z1D-RYx1fDGr96_lMpz?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# uRC6l4lbBVWqY_cBLsEeBDjCmAHMWKgJdjLb7Z1D-RYx1fDGr96_lMpz
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/y8DB5pYX0kJw5KT-nVA1qjVfOXHdoSFx0yR96Mp3FpskDXU?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# y8DB5pYX0kJw5KT-nVA1qjVfOXHdoSFx0yR96Mp3FpskDXU
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/XHgx4XoGs910DVj75YpBjw--0UBAtvbmKZftffTFynxAv_8Xb7GNbz0r?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# XHgx4XoGs910DVj75YpBjw--0UBAtvbmKZftffTFynxAv_8Xb7GNbz0r
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/F-zWsE50cnxy8zqFSFpctcriwqWb0LQOk5LaHbz1pesgLxyBkXKSYuA6?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# F-zWsE50cnxy8zqFSFpctcriwqWb0LQOk5LaHbz1pesgLxyBkXKSYuA6
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/xGkY0loh0dVzc9xQ4YATvBa0e4pi0tAGhp6lz6--DoUyR9Q?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# xGkY0loh0dVzc9xQ4YATvBa0e4pi0tAGhp6lz6--DoUyR9Q
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/GTZxuNyE-n8mGv6ZNUPG0rr9icRwhhL7H7bU57som46RdkI?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# GTZxuNyE-n8mGv6ZNUPG0rr9icRwhhL7H7bU57som46RdkI
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/RmMj-w7o_bAZi_dEj3sqvnq0cOvhbWI-Xc3laJLd1QffyvOZDLjmOOg5?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# RmMj-w7o_bAZi_dEj3sqvnq0cOvhbWI-Xc3laJLd1QffyvOZDLjmOOg5
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/XdTS1bUoc79yzEsri_-8rt9fCllaaUVe_wQxStxBUqyqsOBk4Gvg5IaY?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# XdTS1bUoc79yzEsri_-8rt9fCllaaUVe_wQxStxBUqyqsOBk4Gvg5IaY
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/aFflf5yyp8CRdceVARcu9kuGjnupxaKMy-EDRYqfezxpwAmmoUaOoqzI?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# aFflf5yyp8CRdceVARcu9kuGjnupxaKMy-EDRYqfezxpwAmmoUaOoqzI
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/IggKeI5JM9tX8zJPlSB0S3myVkwO10YIMTXvkLHLP7kPy9k?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# IggKeI5JM9tX8zJPlSB0S3myVkwO10YIMTXvkLHLP7kPy9k
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/HLbeVcSZNL7QENOd9t4lXBJh46hlx1RGKJKB9UmYXQBu_LTbSy8x8mpY?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# HLbeVcSZNL7QENOd9t4lXBJh46hlx1RGKJKB9UmYXQBu_LTbSy8x8mpY
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/VIiK51Jx-8boENc0UpgtXEx4SZNJNtmY0DwahonI6ljPzR-DkyJaa8v9?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# VIiK51Jx-8boENc0UpgtXEx4SZNJNtmY0DwahonI6ljPzR-DkyJaa8v9
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/jlEcgFbfio8v6B8KnXO0_kZPhbct2_KcpPBRrASRYeOuBxk?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# jlEcgFbfio8v6B8KnXO0_kZPhbct2_KcpPBRrASRYeOuBxk
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/vjqJR4jZd6h5bNdIdfrg55ck22TM5kQDjGFJ_QrIuniz?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# vjqJR4jZd6h5bNdIdfrg55ck22TM5kQDjGFJ_QrIuniz
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/4b4SbEus4r70uwBYVstuMGfgw-HSH6ECb92p14aYZhQQ0-Q?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 4b4SbEus4r70uwBYVstuMGfgw-HSH6ECb92p14aYZhQQ0-Q
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/QeQMEcZoIvdtdMCroxqBcN47u6zQ-pb9CTNtTrBpva_--Q4?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# QeQMEcZoIvdtdMCroxqBcN47u6zQ-pb9CTNtTrBpva_--Q4
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/8VuFIjGon1j7ZbxmREq8a9cZUbsF9V6E1iSPQgjFZJPBil44qr4VaDDj?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 8VuFIjGon1j7ZbxmREq8a9cZUbsF9V6E1iSPQgjFZJPBil44qr4VaDDj
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/U8Y5AU22E1Nha6BGBRA4cVY4Q2XQn6-FkQcS0gDbtAeU?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# U8Y5AU22E1Nha6BGBRA4cVY4Q2XQn6-FkQcS0gDbtAeU
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/4qlsc1DSTxyqGiCwOe9W6KChtW0IuI_LYIOrlxqK2DfvbwSFhpldgDTL?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 4qlsc1DSTxyqGiCwOe9W6KChtW0IuI_LYIOrlxqK2DfvbwSFhpldgDTL
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/WzPPb6kNvMWAjLrPIhgWIb5aobwFyITZOqevMq_qXn47jc8eYyOPj3gL?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# WzPPb6kNvMWAjLrPIhgWIb5aobwFyITZOqevMq_qXn47jc8eYyOPj3gL
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/ofvc37BSq9sgjD5HlPnmL2rpK6PnzoysHhuLNDL-WEn_z5ec2o_dmKRY?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# ofvc37BSq9sgjD5HlPnmL2rpK6PnzoysHhuLNDL-WEn_z5ec2o_dmKRY
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/mDU-1aRKhAyKEVXbYS5QL10XAaxltjsENkHXVrFuyLNEl1s?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# mDU-1aRKhAyKEVXbYS5QL10XAaxltjsENkHXVrFuyLNEl1s
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/qmXxJW9-_-_-ShOVvQg55wv7KmHCHGTZRdo90yBmMqq1xxk?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# qmXxJW9-_-_-ShOVvQg55wv7KmHCHGTZRdo90yBmMqq1xxk
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/0LCq1PhzJB8w9QnYEEp-3Fu3YRgkp8XS1r6mAo5qLkkw?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 0LCq1PhzJB8w9QnYEEp-3Fu3YRgkp8XS1r6mAo5qLkkw
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/GawuW6ZLehN2z3jHqoh_dlnknleJU5i2Rkygk-lmbPI3W0eow0d2i7ZJ?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# GawuW6ZLehN2z3jHqoh_dlnknleJU5i2Rkygk-lmbPI3W0eow0d2i7ZJ
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/yocdi-WzeMxDz_dxONbJ_0BcskZjtoQXoAm__ZxAtItduy0wgjd5najh?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# yocdi-WzeMxDz_dxONbJ_0BcskZjtoQXoAm__ZxAtItduy0wgjd5najh
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/EaqOEtwrtUJC3LqOhpthi9FOje6k0eB1cTS0caU8HQpZCRY?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# EaqOEtwrtUJC3LqOhpthi9FOje6k0eB1cTS0caU8HQpZCRY
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/mNtSzMA0XKMf8mzhNMHX-zz6eopB4KszzsdF8B-C8ScdU2A?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# mNtSzMA0XKMf8mzhNMHX-zz6eopB4KszzsdF8B-C8ScdU2A
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/vfPck4ew467Q5TCaOs4KjEXL75-Yo2_ajiGExN-W-JdTTBo?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# vfPck4ew467Q5TCaOs4KjEXL75-Yo2_ajiGExN-W-JdTTBo
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/1Pylba5MFFVKj4AKYJsDhDxnuLfjvfDvDq34wUdqr1RcMTM?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 1Pylba5MFFVKj4AKYJsDhDxnuLfjvfDvDq34wUdqr1RcMTM
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/4xsOnj4G90rEP4OZW37JqhRq0gGA5t18b-jzEsVVsc4gr8w?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 4xsOnj4G90rEP4OZW37JqhRq0gGA5t18b-jzEsVVsc4gr8w
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/2IH3Da_fu2VJxUCGlEKMgvJKbGuDXUGXOKRXHekOH5I3evzzHfDeL6OR?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# 2IH3Da_fu2VJxUCGlEKMgvJKbGuDXUGXOKRXHekOH5I3evzzHfDeL6OR
# https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/BvFS66ybtXVSTqrPhXs47NGyYV6-XAFLT7vchSIpZ0g-H3k?champion=166&beginTime=1627077600000&api_key=RGAPI-3a0389a6-f001-48b2-ac2b-b226fa0300f8
# BvFS66ybtXVSTqrPhXs47NGyYV6-XAFLT7vchSIpZ0g-H3k
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-856da26fd438> in <module>
#      21                 match_req = requests.get(matchlists.format(account_id_pickle_data[x],champion_num,begin_time))
#      22
# ---> 23             elif match_req.status_code == 200 or match_req.status_code == 404 or match_req.status_code == 403:
#      24                 break
#      25     if match_req.status_code == 404 or match_req.status_code == 403:
#
# KeyboardInterrupt:

# %%
with open( "game_id_list", "wb" ) as file:
    pickle.dump( game_id, file)

# %%
with open( "game_id_list", "rb" ) as file:     #load pickle
    game_id_pickle_data = pickle.load(file)
game_id_pickle_data
champion_num = 166    #akshan

# %%
game_id_URL = "https://kr.api.riotgames.com/lol/match/v4/matches/{}?api_key="+api_key
match_info = []
#match data collect

for x in range(len(game_id_pickle_data)):
    game_id_req = requests.get(game_id_URL.format(game_id_pickle_data[x]))
    
    if game_id_req.status_code == 404 or game_id_req.status_code == 403:
        continue
    elif game_id_req.status_code == 200:
        pass
    
    elif game_id_req.status_code == 429:
        start_time = time.time()
        while True:
            if game_id_req.status_code == 429:
                time.sleep(82)

                game_id_req = requests.get(game_id_URL.format(game_id_pickle_data[x]))

            elif game_id_req.status_code == 200 or game_id_req.status_code == 404:
                break
    if game_id_req.status_code == 404 or game_id_req.status_code == 403:
        continue
    if game_id_req.json()['queueId'] != 420:  #only solo rank data
        continue
    for x in range(10):
        if game_id_req.json()['participants'][x]['championId'] == champion_num:
            match_info.append(game_id_req.json()['participants'][x])

# %%
with open( "akshan_match_list", "wb" ) as file:
    pickle.dump( match_info, file)

# %%
with open( "akshan_match_list", "rb" ) as file:     #load pickle
    akshan_match_data = pickle.load(file)

# %%
LOL_data_info_URL = "http://ddragon.leagueoflegends.com/cdn/11.15.1/data/en_US/item.json"
LOL_data_info_req =  requests.get(LOL_data_info_URL)
items_keys = list(LOL_data_info_req.json()['data'].keys())
items_dict = {}        #LOL item data
for x in range(len(items_keys)):
    items_dict[items_keys[x]] = LOL_data_info_req.json()['data'][items_keys[x]]['name']
print(items_dict)

# %%
LOL_spell_data_URL = "http://ddragon.leagueoflegends.com/cdn/11.15.1/data/en_US/summoner.json"
LOL_spell_data_req = requests.get(LOL_spell_data_URL)
spell_keys = list(LOL_spell_data_req.json()['data'].keys())
spells_dict = {}            #LOL spell data
for x in range(len(spell_keys)):
    spells_dict[spell_keys[x]] = LOL_spell_data_req.json()['data'][spell_keys[x]]['key']
print(spells_dict)

# %%
stats_keys = ['spell1Id', 'spell2Id', 'win', 'item0', 'item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'kills', 'deaths', 'assists', 'doubleKills', 'tripleKills', 'quadraKills', 'pentaKills', 'totalDamageDealtToChampions', 'magicDamageDealtToChampions', 'physicalDamageDealtToChampions', 'trueDamageDealtToChampions', 'visionScore', 'goldEarned', 'turretKills', 'inhibitorKills', 'totalMinionsKilled', 'champLevel', 'firstBloodKill', 'firstTowerKill', 'perk0', 'perk0Var1', 'perk0Var2', 'perk0Var3', 'perk1', 'perk1Var1', 'perk1Var2', 'perk1Var3', 'perk2', 'perk2Var1', 'perk2Var2', 'perk2Var3', 'perk3', 'perk3Var1', 'perk3Var2', 'perk3Var3', 'perk4', 'perk4Var1', 'perk4Var2', 'perk4Var3', 'perk5', 'perk5Var1', 'perk5Var2', 'perk5Var3', 'perkPrimaryStyle', 'perkSubStyle', 'statPerk0', 'statPerk1', 'statPerk2']

# %%
akshan_df = []     #make dataframe
for x in range(len(akshan_match_data)):
    data_list = []
    for k in range(len(stats_keys)):
        if k < 2:
            data_list.append(akshan_match_data[x][stats_keys[k]])
        else:
            if stats_keys[k] in akshan_match_data[x]['stats']:
                data_list.append(akshan_match_data[x]['stats'][stats_keys[k]])
            else:
                data_list.append('NaN')
    akshan_df.append(data_list)

# %%
akshan_df = pd.DataFrame(akshan_df)
akshan_df.columns = stats_keys
akshan_df

# %%
akshan_df['win'].value_counts()

# %%
figure.set_size_inches(18,8)
sns.boxplot(x = "kills", orient = "v", data = akshan_df)
